# %% [markdown]
# ## 빅데이터 실습
#
# ### 스타벅스 매장 입지 분석
#
# #### 데이터 수집
#
# #### 웹사이트 제공 엑셀파일 수정

# %%
# 필수 라이브러리 사용등록
import pandas as pd
import numpy as np

# %%
dfSeoulGeo = pd.read_excel('./data/전국_시군구_위경도.xlsx')
dfSeoulGeo.tail()
# Out:
#       docity  do   city   longitude   latitude
# 290    충청충주시  충청    충주시  127.928144  36.988181
# 291    충청태안군  충청    태안군  126.299975  36.742667
# 292  충청한누리대로  충청  한누리대로  127.289926  36.485450
# 293    충청홍성군  충청    홍성군  126.662908  36.598361
# 294    충청대전시  충청    대전시  127.384862  36.350630

# %%
# 서울 필터링
condition = dfSeoulGeo['do'] == '서울'
dfSeoulGeo[condition]
# Out:
#      docity  do  city   longitude   latitude
# 138   서울강남구  서울   강남구  127.049556  37.514575
# 139   서울강동구  서울   강동구  127.125864  37.527367
# 140   서울강북구  서울   강북구  127.027719  37.636956
# 141   서울강서구  서울   강서구  126.851675  37.548156
# 142   서울관악구  서울   관악구  126.953844  37.475386
# 143   서울광진구  서울   광진구  127.084533  37.535739
# 144   서울구로구  서울   구로구  126.889597  37.492650
# 145   서울금천구  서울   금천구  126.904197  37.449108
# 146   서울노원구  서울   노원구  127.058389  37.651461
# 147   서울도봉구  서울   도봉구  127.049522  37.665833
# 148  서울동대문구  서울  동대문구  127.042142  37.571625
# 149   서울동작구  서울   동작구  126.941575  37.509656
# 150   서울마포구  서울   마포구  126.910531  37.560706
# 151  서울서대문구  서울  서대문구  126.938897  37.576367
# 152   서울서초구  서울   서초구  127.034811  37.480786
# 153   서울성동구  서울   성동구  127.039000  37.560611
# 154   서울성북구  서울   성북구  127.020333  37.586383
# 155   서울송파구  서울   송파구  127.107931  37.511756
# 156   서울양천구  서울   양천구  126.868708  37.514231
# 157  서울영등포구  서울  영등포구  126.898342  37.523611
# ...

# %%
dfSeoulGeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     295 non-null    object
#  1   do         295 non-null    object
#  2   city       295 non-null    object
#  3   longitude  295 non-null    float64
#  4   latitude   295 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 11.7+ KB

# %%
# 필요로 만든 서울 데이터는 항상 저장
dfSeoulGeo.to_excel('./data/수정_서울_시군구_위경도.xlsx', index=False)

# %%
## 서울시 구별 인구데이터 로드
dfSeoulGeo = pd.read_excel('./data/서울시_구별_인구데이터.xlsx')
dfSeoulGeo
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     동별(1)  동별(2) 2023 3/4 2023 3/4.1 2023 3/4.2 2023 3/4.3 2023 3/4.4  \
# 0   동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1   동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2      합계     소계  4475726    9655918    4660459    4995459    9407540
# 3     NaN    종로구    72304     151127      72222      78905     139945
# 4     NaN     중구    64609     131825      63661      68164     121405
# 5     NaN    용산구   109360     230692     111646     119046     216152
# 6     NaN    성동구   133366     285543     138109     147434     278366
# 7     NaN    광진구   170388     351959     168059     183900     336604
# 8     NaN   동대문구   173091     359113     173936     185177     341238
# ...
